# %%
#pip install smolagents
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os 
os.environ["HF_TOKEN"]="Enter your hugging face token here"

# %%
#from smolagents import CodeAgent, DuckDuckGoSearchTool, HfApiModel

from smolagents import CodeAgent, DuckDuckGoSearchTool, TransformersModel
#if you get any error using HfApiModel, try using TransformersModel instead

# %%
# %pip install duckduckgo-search
# %pip install smolagents[transformers]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/4.0 MB 7.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 7.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ----------------------- ---------------- 1.8/3.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 8.6 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
#    -------------------------- ------------- 2/3 [duckduckgo-search]
# ...

# %%
#model = HfApiModel()
model = TransformersModel()
agent = CodeAgent(tools=[DuckDuckGoSearchTool()], model=model)
# Out:
# C:\Users\anilk\AppData\Roaming\Python\Python313\site-packages\smolagents\models.py:897: FutureWarning: The 'model_id' parameter will be required in version 2.0.0. Please update your code to pass this parameter to avoid future errors. For now, it defaults to 'HuggingFaceTB/SmolLM2-1.7B-Instruct'.
#   warnings.warn(
# C:\Users\anilk\AppData\Roaming\Python\Python313\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\anilk\.cache\huggingface\hub\models--HuggingFaceTB--SmolLM2-1.7B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
agent.run('differential human brian & machine brian')

# %%
from smolagents import ToolCallingAgent

# %%
tool_agent = ToolCallingAgent(tools=[DuckDuckGoSearchTool()], model = model)

# %%
tool_agent.run('agentic job market in 2025')
